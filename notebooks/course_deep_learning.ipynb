# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinCandra9999/colab-test/blob/main/notebooks/course_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # Bagian Baru

# %%
# !pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.4/286.4 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 51.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 33.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 12.4 MB/s eta 0:00:00
# ...

# %%
import scrapy

# %%
# !pip uninstall scrapy
# Out:
# Found existing installation: Scrapy 2.11.0
# Uninstalling Scrapy-2.11.0:
#   Would remove:
#     /usr/local/bin/scrapy
#     /usr/local/lib/python3.10/dist-packages/Scrapy-2.11.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/scrapy/*
# Proceed (Y/n)? y
#   Successfully uninstalled Scrapy-2.11.0

# %%
# !pip freeze
# Out:
# absl-py==1.4.0
# aiohttp==3.8.6
# aiosignal==1.3.1
# alabaster==0.7.13
# albumentations==1.3.1
# altair==4.2.2
# anyio==3.7.1
# appdirs==1.4.4
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# array-record==0.5.0
# arviz==0.15.1
# astropy==5.3.4
# astunparse==1.6.3
# async-timeout==4.0.3
# atpublic==4.0
# attrs==23.1.0
# audioread==3.0.1
# autograd==1.6.2
# Automat==22.10.0
# Babel==2.13.1
# backcall==0.2.0
# beautifulsoup4==4.11.2
# bidict==0.22.1
# bigframes==0.10.0
# bleach==6.1.0
# blinker==1.4
# blis==0.7.11
# blosc2==2.0.0
# bokeh==3.2.2
# bqplot==0.12.42
# branca==0.6.0
# build==1.0.3
# CacheControl==0.13.1
# cachetools==5.3.2
# catalogue==2.0.10
# certifi==2023.7.22
# cffi==1.16.0
# chardet==5.2.0
# charset-normalizer==3.3.1
# chex==0.1.7
# click==8.1.7
# click-plugins==1.1.1
# cligj==0.7.2
# cloudpickle==2.2.1
# cmake==3.27.7
# cmdstanpy==1.2.0
# colorcet==3.0.1
# colorlover==0.3.0
# colour==0.1.5
# community==1.0.0b1
# confection==0.1.3
# cons==0.4.6
# ...

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
with open('/content/gdrive/My Drive/local.txt', 'r') as f:
  print(f.read())
# Out:
# Hello From Local Machine!

# %%
with open('/content/gdrive/My Drive/colab.txt', 'w') as f:
  f.write('Hello From Google Colab')

# %%
from google.colab import files

uploaded = files.upload()

for filename in uploaded.keys():
  print(uploaded[filename])
# Out:
#      <input type="file" id="files-2db8376d-79ac-4a48-afee-75ab067481e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2db8376d-79ac-4a48-afee-75ab067481e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open('colab.txt','w') as f:
    f.write('hello from google colab!')

files.download('colab.txt')

# %%
# !wget 25.io/toau/audio/sample.txt
# Out:
# --2023-10-30 04:18:54--  http://25.io/toau/audio/sample.txt
# Resolving 25.io (25.io)... 192.169.145.195
# Connecting to 25.io (25.io)|192.169.145.195|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-10-30 04:18:54 ERROR 404: Not Found.
